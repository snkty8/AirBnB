# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/snkty/OneDrive/Desktop/My_Projects/Tableau/New_Orleans_AirBnB/listings.csv')

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df2 = df.filter(items = ['id',
                         'name',
                         'description',
                         'neighborhood_overview',
                         'host_name',
                         'host_since',
                         'host_location', 
                         'host_response_time', 
                         'host_acceptance_rate', 
                         'host_total_listings_count',
                         'latitude', 
                         'longitude', 
                         'property_type',
                         'room_type', 
                         'accommodates',
                         'bathrooms',
                         'bathrooms_text', 
                         'bedrooms',
                         'beds', 
                         'amenities', 
                         'price', 
                         'minimum_nights', 
                         'maximum_nights', 
                         'number_of_reviews', 
                         'review_scores_rating', 
                         'review_scores_cleanliness',
                         'review_scores_checkin',
                         'review_scores_communication', 
                         'review_scores_location', 
                         'review_scores_value'])
df2
# Out:
#                        id                                              name  \
# 0                   19091                    Fully Furnished Cozy Apartment
# 1                   71624                Ravenwood Manor (Historic Bywater)
# 2                   74498               Maison Marais 1: Large Local Living
# 3                   79536                 FeelAtHomeInNewOrleans-PrivateApt
# 4                   79609   Moon Over Mazant - FIRST and FINEST in Bywater!
# ...                   ...                                               ...
# 7248  1108085930318924876                        Gorgeous Uptown NOLA Suite
# 7249  1108090238689884268  Renovated Retreat with Heated Pool | Steps to FQ
# 7250  1108873819642943328                  The Bartholomew - Bywater's Best
# 7251  1108995530911454316                             Jazzy vibrant getaway
# 7252  1109317593885640515              Beautiful Condo near French Quarter!
#
# ...

# %%
df2.drop_duplicates()
# Out:
#                        id                                              name  \
# 0                   19091                    Fully Furnished Cozy Apartment
# 1                   71624                Ravenwood Manor (Historic Bywater)
# 2                   74498               Maison Marais 1: Large Local Living
# 3                   79536                 FeelAtHomeInNewOrleans-PrivateApt
# 4                   79609   Moon Over Mazant - FIRST and FINEST in Bywater!
# ...                   ...                                               ...
# 7248  1108085930318924876                        Gorgeous Uptown NOLA Suite
# 7249  1108090238689884268  Renovated Retreat with Heated Pool | Steps to FQ
# 7250  1108873819642943328                  The Bartholomew - Bywater's Best
# 7251  1108995530911454316                             Jazzy vibrant getaway
# 7252  1109317593885640515              Beautiful Condo near French Quarter!
#
# ...

# %%
df2 = df2.dropna()

# %%
df2
# Out:
#                        id                                             name  \
# 1                   71624               Ravenwood Manor (Historic Bywater)
# 2                   74498              Maison Marais 1: Large Local Living
# 3                   79536                FeelAtHomeInNewOrleans-PrivateApt
# 4                   79609  Moon Over Mazant - FIRST and FINEST in Bywater!
# 5                   80869                       Frenchmen House "Red Room"
# ...                   ...                                              ...
# 7110  1087032799477746223                 Centrally Located 2br w/ Balcony
# 7118  1087845305441509231            #1414 Condo Near French Qtr/Superdome
# 7148  1091556182079828530  Charming Oasis | Close to Uptown | Pet Friendly
# 7156  1093684821724531066                       Guest suite in New Orleans
# 7178  1097222571265692132     Convenient Central City Home, Near Superdome
#
#                                             description  \
# ...

# %%
df2.to_csv('C:/Users/snkty/OneDrive/Desktop/My_Projects/Tableau/New_Orleans_AirBnB/listings_2.csv', index = False)
